# %%
import os
from ultralytics import YOLO

# Modelo pré-treinado
model = YOLO("yolo26n.pt")

config_path = '../datasets/dataset_yolo/data.yaml'

# %%
results = model.train(data=config_path, epochs=200, patience=25, batch=32)
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA RTX A4000, 15968MiB)
# ...

# %%
# Gera dados de validação
results = model.val()
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA RTX A4000, 15968MiB)
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 11676.7±1673.0 MB/s, size: 2384.1 KB)
# val: Scanning /home/ec06-g1/Projects/g01/src/license-plate-detection/datasets/dataset_yolo/val/labels.cache... 900 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 900/900 539.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 57/57 17.2it/s 3.3s0.1s
#                    all        900       1800      0.984      0.967      0.993      0.829
#          license-plate        900        900      0.978      0.973      0.993      0.717
#                vehicle        900        900       0.99      0.962      0.993       0.94
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# ...
