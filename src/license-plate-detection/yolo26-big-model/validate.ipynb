# %%
from ultralytics import YOLO

model = YOLO('best.pt')
data_path = '..-/datasets/License-Plates-3/data.yaml'
# data_path = '../datasets/dataset_yolo/data.yaml'

metrics = model.val(data=data_path, classes=[0])
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA RTX A4000, 15968MiB)
# YOLO26n summary (fused): 122 layers, 2,375,031 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4115.6±748.9 MB/s, size: 34.0 KB)
# val: Scanning /home/ec06-g1/Projects/g01/src/license-plate-detection/datasets/License-Plates-3/valid/labels.cache... 70 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 70/70 73.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s0.2s
#                    all         70         84      0.949      0.886      0.943      0.653
# Speed: 1.4ms preprocess, 2.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/ec06-g1/Projects/g01/src/license-plate-detection/yolo26-separate-models/plate-detector/runs/detect/val-4

# %%
from ultralytics import YOLO

model = YOLO('best.pt')
# data_path = '../datasets/License-Plates-3/data.yaml'
data_path = '../datasets/dataset_yolo/data.yaml'

metrics = model.val(data=data_path, classes=[0])
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA RTX A4000, 15968MiB)
# YOLO26n summary (fused): 122 layers, 2,375,031 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1866.4±264.2 MB/s, size: 2450.7 KB)
# val: Scanning /home/ec06-g1/Projects/g01/src/license-plate-detection/datasets/dataset_yolo/val/labels.cache... 900 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 900/900 629.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 57/57 16.7it/s 3.4s0.2s
#                    all        900        900      0.876      0.803      0.826      0.369
# Speed: 0.3ms preprocess, 1.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/ec06-g1/Projects/g01/src/license-plate-detection/yolo26-separate-models/plate-detector/runs/detect/val-6
